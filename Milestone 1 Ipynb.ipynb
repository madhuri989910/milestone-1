# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df= pd.read_csv("C:/Users/ASHISH/OneDrive/Desktop/New folder/doc mad/coffeeQuality.csv")

# %%
df.isnull()
# Out:
#       Unnamed: 0  Species  Owner  Country.of.Origin  Farm.Name  Lot.Number  \
# 0          False    False  False              False      False        True
# 1          False    False  False              False      False        True
# 2          False    False  False              False      False        True
# 3          False    False  False              False      False        True
# 4          False    False  False              False      False        True
# ...          ...      ...    ...                ...        ...         ...
# 1334       False    False  False              False      False       False
# 1335       False    False  False              False      False       False
# 1336       False    False  False              False      False        True
# 1337       False    False  False              False       True        True
# 1338       False    False  False              False       True        True
#
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
print('Before Convertion :')
df['Harvest.Year'].iloc[2:21]
# Out:
# Before Convertion :
# 2                        NaN
# 3                       2014
# 4                       2014
# 5                       2013
# 6                       2012
# 7                     Mar-10
# 8                     Mar-10
# 9                       2014
# 10                      2014
# 11                      2014
# 12                      2014
# 13    Sept 2009 - April 2010
# 14                    Mar-10
# 15                      2014
# 16                May-August
# 17                 2009/2010
# 18                      2015
# 19                      2014
# 20                      2014
# Name: Harvest.Year, dtype: object

# %%
print ('After Convertion :')
df['Harvest.Year'].iloc[2:21]
# Out:
# After Convertion :
# 2                        NaN
# 3                       2014
# 4                       2014
# 5                       2013
# 6                       2012
# 7                     Mar-10
# 8                     Mar-10
# 9                       2014
# 10                      2014
# 11                      2014
# 12                      2014
# 13    Sept 2009 - April 2010
# 14                    Mar-10
# 15                      2014
# 16                May-August
# 17                 2009/2010
# 18                      2015
# 19                      2014
# 20                      2014
# Name: Harvest.Year, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1339 entries, 0 to 1338
# Data columns (total 44 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             1339 non-null   int64
#  1   Species                1339 non-null   object
#  2   Owner                  1332 non-null   object
#  3   Country.of.Origin      1338 non-null   object
#  4   Farm.Name              980 non-null    object
#  5   Lot.Number             276 non-null    object
#  6   Mill                   1021 non-null   object
#  7   ICO.Number             1180 non-null   object
#  8   Company                1130 non-null   object
#  9   Altitude               1113 non-null   object
#  10  Region                 1280 non-null   object
#  11  Producer               1107 non-null   object
#  12  Number.of.Bags         1338 non-null   float64
#  13  Bag.Weight             1339 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                  0
# Species                     0
# Owner                       7
# Country.of.Origin           1
# Farm.Name                 359
# Lot.Number               1063
# Mill                      318
# ICO.Number                159
# Company                   209
# Altitude                  226
# Region                     59
# Producer                  232
# Number.of.Bags              1
# Bag.Weight                  0
# In.Country.Partner          0
# Harvest.Year               47
# Grading.Date                0
# Owner.1                     7
# Variety                   226
# Processing.Method         170
# Aroma                       0
# Flavor                      0
# Aftertaste                  0
# Acidity                     0
# Body                        0
# Balance                     0
# Uniformity                  0
# Clean.Cup                   0
# Sweetness                   0
# Cupper.Points               0
# Total.Cup.Points            0
# ...

# %%
Owner = df.Owner.mode()[0]

# %%
print(Owner)
# Out:
# juan luis alvarado romero

# %%
df.Owner.fillna(Owner,inplace=True)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                  0
# Species                     0
# Owner                       0
# Country.of.Origin           1
# Farm.Name                 359
# Lot.Number               1063
# Mill                      318
# ICO.Number                159
# Company                   209
# Altitude                  226
# Region                     59
# Producer                  232
# Number.of.Bags              1
# Bag.Weight                  0
# In.Country.Partner          0
# Harvest.Year               47
# Grading.Date                0
# Owner.1                     7
# Variety                   226
# Processing.Method         170
# Aroma                       0
# Flavor                      0
# Aftertaste                  0
# Acidity                     0
# Body                        0
# Balance                     0
# Uniformity                  0
# Clean.Cup                   0
# Sweetness                   0
# Cupper.Points               0
# Total.Cup.Points            0
# ...

# %%
Mill = df.Mill.mode()[0]

# %%
print(Mill)
# Out:
# beneficio ixchel

# %%
df.Mill.fillna(Owner,inplace=True)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                  0
# Species                     0
# Owner                       0
# Country.of.Origin           1
# Farm.Name                 359
# Lot.Number               1063
# Mill                        0
# ICO.Number                159
# Company                   209
# Altitude                  226
# Region                     59
# Producer                  232
# Number.of.Bags              1
# Bag.Weight                  0
# In.Country.Partner          0
# Harvest.Year               47
# Grading.Date                0
# Owner.1                     7
# Variety                   226
# Processing.Method         170
# Aroma                       0
# Flavor                      0
# Aftertaste                  0
# Acidity                     0
# Body                        0
# Balance                     0
# Uniformity                  0
# Clean.Cup                   0
# Sweetness                   0
# Cupper.Points               0
# Total.Cup.Points            0
# ...

# %%
Company = df.Company.mode()[0]

# %%
print(Company)
# Out:
# unex guatemala, s.a.

# %%
df.Company.fillna(Owner,inplace=True)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                  0
# Species                     0
# Owner                       0
# Country.of.Origin           1
# Farm.Name                 359
# Lot.Number               1063
# Mill                        0
# ICO.Number                159
# Company                     0
# Altitude                  226
# Region                     59
# Producer                  232
# Number.of.Bags              1
# Bag.Weight                  0
# In.Country.Partner          0
# Harvest.Year               47
# Grading.Date                0
# Owner.1                     7
# Variety                   226
# Processing.Method         170
# Aroma                       0
# Flavor                      0
# Aftertaste                  0
# Acidity                     0
# Body                        0
# Balance                     0
# Uniformity                  0
# Clean.Cup                   0
# Sweetness                   0
# Cupper.Points               0
# Total.Cup.Points            0
# ...

# %%
Altitude = df.Altitude.mode()[0]

# %%
print(Altitude)
# Out:
# 1100

# %%
df.Altitude.fillna(Altitude,inplace=True)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                  0
# Species                     0
# Owner                       0
# Country.of.Origin           1
# Farm.Name                 359
# Lot.Number               1063
# Mill                        0
# ICO.Number                159
# Company                     0
# Altitude                    0
# Region                     59
# Producer                  232
# Number.of.Bags              1
# Bag.Weight                  0
# In.Country.Partner          0
# Harvest.Year               47
# Grading.Date                0
# Owner.1                     7
# Variety                   226
# Processing.Method         170
# Aroma                       0
# Flavor                      0
# Aftertaste                  0
# Acidity                     0
# Body                        0
# Balance                     0
# Uniformity                  0
# Clean.Cup                   0
# Sweetness                   0
# Cupper.Points               0
# Total.Cup.Points            0
# ...

# %%
Region = df.Region.mode()[0]

# %%
print(Region)
# Out:
# huila

# %%
df.Region.fillna(Region,inplace=True)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                  0
# Species                     0
# Owner                       0
# Country.of.Origin           1
# Farm.Name                 359
# Lot.Number               1063
# Mill                        0
# ICO.Number                159
# Company                     0
# Altitude                    0
# Region                      0
# Producer                  232
# Number.of.Bags              1
# Bag.Weight                  0
# In.Country.Partner          0
# Harvest.Year               47
# Grading.Date                0
# Owner.1                     7
# Variety                   226
# Processing.Method         170
# Aroma                       0
# Flavor                      0
# Aftertaste                  0
# Acidity                     0
# Body                        0
# Balance                     0
# Uniformity                  0
# Clean.Cup                   0
# Sweetness                   0
# Cupper.Points               0
# Total.Cup.Points            0
# ...

# %%
Producer  = df.Producer.mode()[0]

# %%
print(Producer)
# Out:
# La Plata

# %%
df.Producer.fillna(Producer,inplace=True)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                  0
# Species                     0
# Owner                       0
# Country.of.Origin           1
# Farm.Name                 359
# Lot.Number               1063
# Mill                        0
# ICO.Number                159
# Company                     0
# Altitude                    0
# Region                      0
# Producer                    0
# Number.of.Bags              1
# Bag.Weight                  0
# In.Country.Partner          0
# Harvest.Year               47
# Grading.Date                0
# Owner.1                     7
# Variety                   226
# Processing.Method         170
# Aroma                       0
# Flavor                      0
# Aftertaste                  0
# Acidity                     0
# Body                        0
# Balance                     0
# Uniformity                  0
# Clean.Cup                   0
# Sweetness                   0
# Cupper.Points               0
# Total.Cup.Points            0
# ...

# %%
Variety   = df.Variety .mode()[0]

# %%
print(Variety)
# Out:
# Caturra

# %%
df.Variety.fillna(Variety,inplace=True)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                  0
# Species                     0
# Owner                       0
# Country.of.Origin           1
# Farm.Name                 359
# Lot.Number               1063
# Mill                        0
# ICO.Number                159
# Company                     0
# Altitude                    0
# Region                      0
# Producer                    0
# Number.of.Bags              1
# Bag.Weight                  0
# In.Country.Partner          0
# Harvest.Year               47
# Grading.Date                0
# Owner.1                     7
# Variety                     0
# Processing.Method         170
# Aroma                       0
# Flavor                      0
# Aftertaste                  0
# Acidity                     0
# Body                        0
# Balance                     0
# Uniformity                  0
# Clean.Cup                   0
# Sweetness                   0
# Cupper.Points               0
# Total.Cup.Points            0
# ...

# %%
Quakers   = df.Quakers.mode()[0]

# %%
print(Quakers )
# Out:
# 0.0

# %%
df.Quakers.fillna(Quakers,inplace=True)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                  0
# Species                     0
# Owner                       0
# Country.of.Origin           1
# Farm.Name                 359
# Lot.Number               1063
# Mill                        0
# ICO.Number                159
# Company                     0
# Altitude                    0
# Region                      0
# Producer                    0
# Number.of.Bags              1
# Bag.Weight                  0
# In.Country.Partner          0
# Harvest.Year               47
# Grading.Date                0
# Owner.1                     7
# Variety                     0
# Processing.Method         170
# Aroma                       0
# Flavor                      0
# Aftertaste                  0
# Acidity                     0
# Body                        0
# Balance                     0
# Uniformity                  0
# Clean.Cup                   0
# Sweetness                   0
# Cupper.Points               0
# Total.Cup.Points            0
# ...

# %%
Color  = df.Color.mode()[0]

# %%
print(Color )
# Out:
# Green

# %%
df.Color.fillna(Color,inplace=True)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                  0
# Species                     0
# Owner                       0
# Country.of.Origin           1
# Farm.Name                 359
# Lot.Number               1063
# Mill                        0
# ICO.Number                159
# Company                     0
# Altitude                    0
# Region                      0
# Producer                    0
# Number.of.Bags              1
# Bag.Weight                  0
# In.Country.Partner          0
# Harvest.Year               47
# Grading.Date                0
# Owner.1                     7
# Variety                     0
# Processing.Method         170
# Aroma                       0
# Flavor                      0
# Aftertaste                  0
# Acidity                     0
# Body                        0
# Balance                     0
# Uniformity                  0
# Clean.Cup                   0
# Sweetness                   0
# Cupper.Points               0
# Total.Cup.Points            0
# ...

# %%
df1=df[['Number.of.Bags','Aroma','Flavor','Aftertaste','Acidity','Body','Balance','Uniformity','Clean.Cup','Sweetness','Cupper.Points','Total.Cup.Points','Moisture','Category.One.Defects','Quakers','Category.Two.Defects','altitude_low_meters','altitude_high_meters','altitude_mean_meters']]

# %%
df1
# Out:
#       Number.of.Bags  Aroma  Flavor  Aftertaste  Acidity  Body  Balance  \
# 0              300.0   8.67    8.83        8.67     8.75  8.50     8.42
# 1              300.0   8.75    8.67        8.50     8.58  8.42     8.42
# 2                5.0   8.42    8.50        8.42     8.42  8.33     8.42
# 3              320.0   8.17    8.58        8.42     8.42  8.50     8.25
# 4              300.0   8.25    8.50        8.25     8.50  8.42     8.33
# ...              ...    ...     ...         ...      ...   ...      ...
# 1334             1.0   7.75    7.58        7.33     7.58  5.08     7.83
# 1335             1.0   7.50    7.67        7.75     7.75  5.17     5.25
# 1336             1.0   7.33    7.33        7.17     7.42  7.50     7.17
# 1337             1.0   7.42    6.83        6.75     7.17  7.25     7.00
# 1338             1.0   6.75    6.67        6.50     6.83  6.92     6.83
#
#       Uniformity  Clean.Cup  Sweetness  Cupper.Points  Total.Cup.Points  \
# ...

# %%
Q1 = df1.quantile(0.25)
Q3 = df1.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# Number.of.Bags          261.00
# Aroma                     0.33
# Flavor                    0.42
# Aftertaste                0.33
# Acidity                   0.42
# Body                      0.34
# Balance                   0.42
# Uniformity                0.00
# Clean.Cup                 0.00
# Sweetness                 0.00
# Cupper.Points             0.50
# Total.Cup.Points          2.59
# Moisture                  0.03
# Category.One.Defects      0.00
# Quakers                   0.00
# Category.Two.Defects      4.00
# altitude_low_meters     500.00
# altitude_high_meters    550.00
# altitude_mean_meters    500.00
# dtype: float64

# %%
a=(df1 < (Q1 - 1.5 * IQR)) | (df1 > (Q3 + 1.5 * IQR))

# %%
a.sum()
# Out:
# Number.of.Bags            4
# Aroma                    75
# Flavor                   44
# Aftertaste               87
# Acidity                  25
# Body                     34
# Balance                  40
# Uniformity              187
# Clean.Cup               120
# Sweetness               121
# Cupper.Points            33
# Total.Cup.Points         72
# Moisture                305
# Category.One.Defects    202
# Quakers                  94
# Category.Two.Defects     94
# altitude_low_meters      66
# altitude_high_meters     62
# altitude_mean_meters     66
# dtype: int64

# %%
boston_c = df1
fig, ax = plt.subplots(figsize=(19,9))
ax.scatter(boston_c['Aroma'], boston_c['Flavor'])
ax.set_xlabel('proportion of non-retail business acres per town')
ax.set_ylabel('full-value property-tax rate per $10,000')
plt.show()

# %%
from scipy import stats
import numpy as np
zscore = np.abs(stats.zscore(boston_c))
print(zscore)
# Out:
#       Number.of.Bags     Aroma    Flavor  Aftertaste   Acidity      Body  \
# 0                NaN  0.162645  3.287965    3.138457  3.198164  2.655944
# 1                NaN  0.177105  2.886251    2.717990  2.750424  2.439684
# 2                NaN  0.117457  2.459430    2.520123  2.329022  2.196392
# 3                NaN  0.072268  2.660287    2.520123  2.329022  2.655944
# 4                NaN  0.086728  2.459430    2.099656  2.539723  2.439684
# ...              ...       ...       ...         ...       ...       ...
# 1334             NaN  0.003649  0.149574    0.175812  0.116661  6.589155
# 1335             NaN  0.048837  0.375538    0.862989  0.564400  6.345863
# 1336             NaN  0.079566  0.478104    0.571545  0.304742  0.047302
# 1337             NaN  0.063298  1.733461    1.610346  0.963182  0.723113
# 1338             NaN  0.184403  2.135175    2.228680  1.858662  1.615184
#
#        Balance  Uniformity  Clean.Cup  Sweetness  Cupper.Points  \
# ...

# %%
df1.corr()
# Out:
#                       Number.of.Bags     Aroma    Flavor  Aftertaste  \
# Number.of.Bags              1.000000 -0.019525  0.015253    0.021710
# Aroma                      -0.019525  1.000000  0.082375    0.070514
# Flavor                      0.015253  0.082375  1.000000    0.895672
# Aftertaste                  0.021710  0.070514  0.895672    1.000000
# Acidity                     0.039560  0.066924  0.816688    0.792255
# Body                        0.041503  0.083012  0.735720    0.734306
# Balance                     0.044109  0.067435  0.792290    0.809639
# Uniformity                  0.027498  0.035963  0.410923    0.401456
# Clean.Cup                   0.029107  0.030842  0.396958    0.386665
# Sweetness                   0.008785  0.025852  0.291065    0.266409
# Cupper.Points               0.019261  0.068139  0.793197    0.785123
# Total.Cup.Points            0.032983  0.078879  0.874279    0.860656
# Moisture                   -0.029129  0.000547 -0.145201   -0.180510
# ...

# %%
a=df1.corr()
plt.figure(figsize=(6,9))
sns.heatmap(a,annot=True,cmap='Blues')
# Out:
# <Axes: >

# %%
sns.lmplot(x='Aroma',y='Flavor',data=df1)
